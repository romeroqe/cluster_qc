# %% [markdown]
# ## demo3: Visualizing Hydrographic Profiles from an Argo Float
#
# This demo illustrates how to:
#
# 1. Load vertically resolved hydrographic measurements from a selected Argo float.
# 2. Convert practical salinity and in-situ temperature to Absolute Salinity and Conservative Temperature using TEOS-10.
# 3. Compute geometric depth from pressure.
# 4. Generate basic multi-panel visualizations summarizing the float's vertical structure and temporal evolution.

# %%
import pandas as pd
import cluster_qc

# %%
data = pd.read_csv("./data/profile_measurements.csv")
data
# Out:
#          PLATFORM_NUMBER  CYCLE_NUMBER DATA_MODE  \
# 0                1902645             1         A
# 1                1902645             1         A
# 2                1902645             1         A
# 3                1902645             1         A
# 4                1902645             1         A
# ...                  ...           ...       ...
# 1817306          4902475           184         R
# 1817307          4902475           184         R
# 1817308          4902475           184         R
# 1817309          4902475           184         R
# 1817310          4902475           184         R
#
#                                   DATE   LATITUDE   LONGITUDE     PRES  \
# 0        2024-05-23 07:01:06.000752640  20.897200 -111.494100     4.31
# 1        2024-05-23 07:01:06.000752640  20.897200 -111.494100     6.11
# 2        2024-05-23 07:01:06.000752640  20.897200 -111.494100     8.11
# 3        2024-05-23 07:01:06.000752640  20.897200 -111.494100    10.11
# ...

# %%
fig = cluster_qc.plot_six_diagrams(data[data.PLATFORM_NUMBER==4901635])
